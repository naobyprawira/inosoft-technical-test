# %% [markdown]
# # Inosoft Technical Test - Amazon Stock Price Prediction
# - Naoby Prawira

# %% [markdown]
# # Import Libraries

# %%
# Basic Data and Visualization Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Training Data Processing and Model Development Libraries
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

# For model saving (timestamping and directory management)
import datetime
import os

# %% [markdown]
# # Load Dataset

# %%
df=pd.read_csv('Test Macine Learning Enginer Inosoft_AMZN.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# 1      294000000
# 2      122136000
# 3      109344000
# 4      377064000
# ...          ...
# 6511    53633400
# 6512    56704300
# 6513    41135700
# 6514    48662500
# 6515    45103000
#
# [6516 rows x 7 columns]

# %% [markdown]
# # Set Date as Index

# %%
df.set_index('Date',inplace = True)

# %%
df.index =  pd.to_datetime(df.index,format='%Y-%m-%d') # Convert the index to datetime format

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000

# %% [markdown]
# # Exploratory Data Analysis

# %%
df[['Open','Close','High','Low']].plot(figsize = (20,12))
plt.title('All Columns')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %% [markdown]
# Sesuai instruksi, kita lihat grafik persebaran value dan detect anomali di kolom Close.

# %%
def detect_anomalies(data, column, threshold=3):
    # Calculate rolling mean and std
    rolling_mean = data[column].rolling(window=20).mean()
    rolling_std = data[column].rolling(window=20).std()
    
    # Calculate z-score
    z_score = (data[column] - rolling_mean) / rolling_std
    
    # Identify anomalies
    data['anomaly'] = (abs(z_score) > threshold).astype(int)
    data['z_score'] = z_score
    
    return data

# Apply anomaly detection
anomaly_df = detect_anomalies(df.copy(), 'Close')

# Visualize the anomalies
plt.figure(figsize=(20, 10))
plt.plot(anomaly_df.index, anomaly_df['Close'], label='Close Price')
plt.scatter(anomaly_df[anomaly_df['anomaly'] == 1].index, 
            anomaly_df[anomaly_df['anomaly'] == 1]['Close'], 
            color='red', label='Anomaly')
plt.title('Anomalies in Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Pada grafik di atas, anomali yang dihighlight tidak terlalu signifikan (tetap normal dalam konteks harga saham), sehingga dapat disimpulkan tidak ada kesalahan format atau nilai yang tidak normal.

# %%
df['Close'].plot(figsize = (20,10))
plt.title('Close Price History')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %% [markdown]
# Dari grafik di atas, terlihat bahwa closing price/harga saham Amazon cukup stagnan hingga sekitar 2009, baru setelahnya mengalami kenaikan dan mulai fluktuatif. Maka ada 2 approach yang dapat dilakukan:
# 1. Tetap gunakan keseluruhan data
# 2. Gunakan data mulai dari 2009
#
# Disini saya akan coba approach kedua dengan alasan:
#
# - Terlihat bahwa mulai dari 2009 harga saham cenderung mulai fluktuatif dan seterusnya tidak tampak akan terjadi stagnan,
# - Dengan memilih data training yang variatif, diharapkan model tidak bias ke pola harga yang stagnan dan lebih akurat menangkap pola fluktuatif dari harga saham.

# %%
df = df['2009':'2024']

# %%
df['Close'].plot(figsize = (20,10))
plt.title('Close Price History from 2009 to 2024')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ## Callback function

# %% [markdown]
# Callback function digunakan mengontrol keseluruhan arah model nantinya, seperti:
# 1. Menghentikan training bila mencapai akurasi tertentu untuk mencegah overfitting
# 2. Kembali ke iterasi dengan performa yang terbaik
# 3. Menyimpan weight pada tiap "checkpoint" tertentu, agar jika ada kendala tidak mengharuskan training dari awal (jika tidak memungkinkan).

# %%
# ini callback function yang saya gunakan untuk training model deep learning secara general.

EPOCHS = 150
patience = 10

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.0005

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def getMetrics(type_):
        if type_ == 'accuracy':
            return 'accuracy'
        if type_ == 'loss':
            return 'loss'
        if type_ == 'val_accuracy':
            return 'val_accuracy'
        if type_ == 'val_loss':
            return 'val_loss'

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr
        
def getCallbacks(name):
    class myCallback(Callback):
        def on_epoch_end(self, epoch, logs={}):
            if ((logs.get(getMetrics('loss'))<=0.00001)):
                print("\nLimits Reached cancelling training!")
                self.model.stop_training = True

            
    end_callback = myCallback()

    lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

    lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

    early_stopping = EarlyStopping(patience = patience, monitor=getMetrics('val_loss'),
                                 mode='min', restore_best_weights=True, 
                                 verbose = 1, min_delta = .00075)


    checkpoint_filepath = name + '.weights.h5'

    model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor=getMetrics('val_loss'),
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)

    import datetime
    log_dir="logs/fit/" + '_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")  
    tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

    return [end_callback, 
             lr_callback, 
             model_checkpoints,
             early_stopping,
             #tensorboard_callback,
             lr_plat
            ]
callbacks_ = getCallbacks('Simple_RNN')

# %%
# pisahkan df['close] untuk forecasting
price = df['Close']

# Buat array untuk sequences
X = []
y = []

for i in range(2, len(price)):
    X.append(price[i-2:i])
    y.append(price[i])

X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# C:\Users\naoby\AppData\Local\Temp\ipykernel_13392\1959453963.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y.append(price[i])
# Training data shape: (2869, 2, 1)
# Testing data shape: (718, 2, 1)

# %% [markdown]
# ## Training Model

# %%
# Inisiasi model RNN sesuai instruksi
model = Sequential()
model.add(SimpleRNN(50, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(Dense(25))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# c:\Users\naoby\Downloads\inosoft-technical-test\inosoft-tech-test\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)        │ (None, 50)             │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,901 (15.24 KB)
#  Trainable params: 3,901 (15.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=EPOCHS,
    batch_size=8, 
    validation_split=0.2,
    callbacks=callbacks_,
    verbose=1
)
# Out:
# Epoch 1/150
# 257/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 412.8877
# Epoch 1: val_loss improved from inf to 4610.08594, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 409.7617 - val_loss: 4610.0859 - learning_rate: 1.0000e-05
# Epoch 2/150
# 278/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 185.8877
# Epoch 2: val_loss improved from 4610.08594 to 18.21124, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 182.6530 - val_loss: 18.2112 - learning_rate: 1.0800e-04
# Epoch 3/150
# 278/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3502
# Epoch 3: val_loss improved from 18.21124 to 4.01356, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3481 - val_loss: 4.0136 - learning_rate: 2.0600e-04
# Epoch 4/150
# 276/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2191
# Epoch 4: val_loss improved from 4.01356 to 3.64629, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2198 - val_loss: 3.6463 - learning_rate: 3.0400e-04
# Epoch 5/150
# 272/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2072
# Epoch 5: val_loss did not improve from 3.64629
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2083 - val_loss: 3.7592 - learning_rate: 4.0200e-04
# Epoch 6/150
# 274/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2434
# Epoch 6: val_loss improved from 3.64629 to 3.56639, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2420 - val_loss: 3.5664 - learning_rate: 5.0000e-04
# Epoch 7/150
# 279/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2188
# Epoch 7: val_loss improved from 3.56639 to 3.56170, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2187 - val_loss: 3.5617 - learning_rate: 4.0200e-04
# Epoch 8/150
# 268/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1962
# Epoch 8: val_loss improved from 3.56170 to 3.54472, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1969 - val_loss: 3.5447 - learning_rate: 3.2360e-04
# Epoch 9/150
# 275/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2188
# Epoch 9: val_loss did not improve from 3.54472
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2181 - val_loss: 3.6389 - learning_rate: 2.6088e-04
# Epoch 10/150
# 271/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2014
# Epoch 10: val_loss did not improve from 3.54472
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2008 - val_loss: 3.6770 - learning_rate: 2.1070e-04
# Epoch 11/150
# 283/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2022
# Epoch 11: val_loss improved from 3.54472 to 3.52936, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2022 - val_loss: 3.5294 - learning_rate: 1.7056e-04
# Epoch 12/150
# 270/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2096
# Epoch 12: val_loss did not improve from 3.52936
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2091 - val_loss: 3.5807 - learning_rate: 1.3845e-04
# Epoch 13/150
# 278/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1768
# Epoch 13: val_loss did not improve from 3.52936
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1777 - val_loss: 3.6209 - learning_rate: 1.1276e-04
# Epoch 14/150
# 272/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2131
# Epoch 14: val_loss did not improve from 3.52936
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2123 - val_loss: 3.6301 - learning_rate: 9.2208e-05
# Epoch 15/150
# 275/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2195
# Epoch 15: val_loss did not improve from 3.52936
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2187 - val_loss: 3.5699 - learning_rate: 7.5767e-05
# Epoch 16/150
# 275/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1723
# Epoch 16: val_loss did not improve from 3.52936
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1731 - val_loss: 3.6420 - learning_rate: 6.2613e-05
# Epoch 17/150
# 281/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2021
# Epoch 17: val_loss did not improve from 3.52936
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2020 - val_loss: 3.5443 - learning_rate: 5.2091e-05
# Epoch 18/150
# 269/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1711
# Epoch 18: val_loss did not improve from 3.52936
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1731 - val_loss: 3.5763 - learning_rate: 4.3673e-05
# Epoch 19/150
# 272/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2078
# Epoch 19: val_loss improved from 3.52936 to 3.52323, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2072 - val_loss: 3.5232 - learning_rate: 3.6938e-05
# Epoch 20/150
# 281/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2284
# Epoch 20: val_loss did not improve from 3.52323
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2276 - val_loss: 3.5545 - learning_rate: 3.1550e-05
# Epoch 21/150
# 271/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1619
# Epoch 21: val_loss improved from 3.52323 to 3.52240, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1641 - val_loss: 3.5224 - learning_rate: 2.7240e-05
# Epoch 22/150
# 277/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1776
# Epoch 22: val_loss did not improve from 3.52240
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1783 - val_loss: 3.5336 - learning_rate: 2.3792e-05
# Epoch 23/150
# 281/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2116
# Epoch 23: val_loss did not improve from 3.52240
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2112 - val_loss: 3.5811 - learning_rate: 2.1034e-05
# Epoch 24/150
# 271/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1760
# Epoch 24: val_loss improved from 3.52240 to 3.50806, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1767 - val_loss: 3.5081 - learning_rate: 1.8827e-05
# Epoch 25/150
# 272/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2121
# Epoch 25: val_loss improved from 3.50806 to 3.49818, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2111 - val_loss: 3.4982 - learning_rate: 1.7062e-05
# Epoch 26/150
# 275/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1799
# Epoch 26: val_loss did not improve from 3.49818
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1805 - val_loss: 3.5872 - learning_rate: 1.5649e-05
# Epoch 27/150
# 270/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2035
# Epoch 27: val_loss improved from 3.49818 to 3.49715, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2032 - val_loss: 3.4971 - learning_rate: 1.4519e-05
# Epoch 28/150
# 278/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2266
# Epoch 28: val_loss did not improve from 3.49715
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2256 - val_loss: 3.5514 - learning_rate: 1.3616e-05
# Epoch 29/150
# 269/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1747
# Epoch 29: val_loss improved from 3.49715 to 3.49709, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1761 - val_loss: 3.4971 - learning_rate: 1.2892e-05
# Epoch 30/150
# 272/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1832
# Epoch 30: val_loss did not improve from 3.49709
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1837 - val_loss: 3.5920 - learning_rate: 1.2314e-05
# Epoch 31/150
# 285/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1834
# Epoch 31: val_loss did not improve from 3.49709
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1835 - val_loss: 3.5009 - learning_rate: 1.1851e-05
# Epoch 32/150
# 279/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2386
# Epoch 32: val_loss did not improve from 3.49709
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2373 - val_loss: 3.5811 - learning_rate: 1.1481e-05
# Epoch 33/150
# 281/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2356
# Epoch 33: val_loss did not improve from 3.49709
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2347 - val_loss: 3.5308 - learning_rate: 1.1185e-05
# Epoch 34/150
# 281/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2014
# Epoch 34: val_loss did not improve from 3.49709
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2013 - val_loss: 3.5808 - learning_rate: 1.0948e-05
# Epoch 35/150
# 282/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2171
# Epoch 35: val_loss did not improve from 3.49709
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2166 - val_loss: 3.5138 - learning_rate: 1.0758e-05
# Epoch 36/150
# 279/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2066
# Epoch 36: val_loss improved from 3.49709 to 3.49052, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2062 - val_loss: 3.4905 - learning_rate: 1.0607e-05
# Epoch 37/150
# 271/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1891
# Epoch 37: val_loss did not improve from 3.49052
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1894 - val_loss: 3.5159 - learning_rate: 1.0485e-05
# Epoch 38/150
# 264/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1894
# Epoch 38: val_loss did not improve from 3.49052
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1901 - val_loss: 3.5160 - learning_rate: 1.0388e-05
# Epoch 39/150
# 279/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1708
# Epoch 39: val_loss did not improve from 3.49052
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1716 - val_loss: 3.5220 - learning_rate: 1.0311e-05
# Epoch 40/150
# 269/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1796
# Epoch 40: val_loss did not improve from 3.49052
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1807 - val_loss: 3.5479 - learning_rate: 1.0248e-05
# Epoch 41/150
# 275/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2335
# Epoch 41: val_loss improved from 3.49052 to 3.48469, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2318 - val_loss: 3.4847 - learning_rate: 1.0199e-05
# Epoch 42/150
# 276/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1735
# Epoch 42: val_loss did not improve from 3.48469
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1745 - val_loss: 3.5052 - learning_rate: 1.0159e-05
# Epoch 43/150
# 280/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1856
# Epoch 43: val_loss did not improve from 3.48469
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1858 - val_loss: 3.4942 - learning_rate: 1.0127e-05
# Epoch 44/150
# 274/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1888
# Epoch 44: val_loss did not improve from 3.48469
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1891 - val_loss: 3.5420 - learning_rate: 1.0102e-05
# Epoch 45/150
# 279/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1949
# Epoch 45: val_loss did not improve from 3.48469
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1949 - val_loss: 3.6052 - learning_rate: 1.0081e-05
# Epoch 46/150
# 269/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1665
# Epoch 46: val_loss did not improve from 3.48469
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1684 - val_loss: 3.5766 - learning_rate: 1.0065e-05
# Epoch 47/150
# 275/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1961
# Epoch 47: val_loss did not improve from 3.48469
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1961 - val_loss: 3.5362 - learning_rate: 1.0052e-05
# Epoch 48/150
# 273/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1678
# Epoch 48: val_loss did not improve from 3.48469
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1692 - val_loss: 3.4976 - learning_rate: 1.0042e-05
# Epoch 49/150
# 270/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1803
# Epoch 49: val_loss improved from 3.48469 to 3.47627, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1814 - val_loss: 3.4763 - learning_rate: 1.0033e-05
# Epoch 50/150
# 272/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1578
# Epoch 50: val_loss did not improve from 3.47627
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1598 - val_loss: 3.4793 - learning_rate: 1.0027e-05
# Epoch 51/150
# 273/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1706
# Epoch 51: val_loss did not improve from 3.47627
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1719 - val_loss: 3.5010 - learning_rate: 1.0021e-05
# Epoch 52/150
# 272/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1742
# Epoch 52: val_loss did not improve from 3.47627
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1753 - val_loss: 3.5210 - learning_rate: 1.0017e-05
# Epoch 53/150
# 277/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1830
# Epoch 53: val_loss did not improve from 3.47627
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1835 - val_loss: 3.4766 - learning_rate: 1.0014e-05
# Epoch 54/150
# 276/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1580
# Epoch 54: val_loss did not improve from 3.47627
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1595 - val_loss: 3.5417 - learning_rate: 1.0011e-05
# Epoch 55/150
# 271/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2188
# Epoch 55: val_loss improved from 3.47627 to 3.47100, saving model to Simple_RNN.weights.h5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2175 - val_loss: 3.4710 - learning_rate: 1.0009e-05
# Epoch 56/150
# 270/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1942
# Epoch 56: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1943 - val_loss: 3.5547 - learning_rate: 1.0007e-05
# Epoch 57/150
# 270/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1715
# Epoch 57: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1720 - val_loss: 3.4718 - learning_rate: 1.0006e-05
# Epoch 58/150
# 269/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1908
# Epoch 58: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1906 - val_loss: 3.4813 - learning_rate: 1.0004e-05
# Epoch 59/150
# 283/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2121
# Epoch 59: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2118 - val_loss: 3.5393 - learning_rate: 1.0004e-05
# Epoch 60/150
# 267/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1611
# Epoch 60: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1629 - val_loss: 3.5116 - learning_rate: 1.0003e-05
# Epoch 61/150
# 278/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2225
# Epoch 61: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2215 - val_loss: 3.4757 - learning_rate: 1.0002e-05
# Epoch 62/150
# 270/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1815
# Epoch 62: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1821 - val_loss: 3.5399 - learning_rate: 1.0002e-05
# Epoch 63/150
# 276/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2128
# Epoch 63: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2122 - val_loss: 3.5056 - learning_rate: 1.0001e-05
# Epoch 64/150
# 273/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2101
# Epoch 64: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2092 - val_loss: 3.5163 - learning_rate: 1.0001e-05
# Epoch 65/150
# 283/287 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1853
# Epoch 65: val_loss did not improve from 3.47100
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1855 - val_loss: 3.5037 - learning_rate: 1.0001e-05
# Epoch 65: early stopping
# Restoring model weights from the end of the best epoch: 55.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Model Testing

# %%
# Reshape data testing
X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

training_data_preds = model.predict(X_train)
testing_data_preds = model.predict(X_test)

print('Train rmse:', np.sqrt(mean_squared_error(y_train, training_data_preds)))
print('Validation rmse:', np.sqrt(mean_squared_error(y_test, testing_data_preds)))
# Out:
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Train rmse: 0.921535401316275
# Validation rmse: 3.4394166170292273

# %%
valid = pd.DataFrame(df[2871:])
valid['Predictions']=testing_data_preds 
plt.figure(figsize=(16,8))
plt.title('Prediction Results Comparison')
plt.plot(valid[['Close','Predictions']])
plt.legend(['Validation','Predictions'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16, 8))
plt.plot(df['Close'], label='Actual Close Price')
plt.plot(valid.index, valid['Predictions'], label='Predictions')
plt.title('Visualization of Amazon Stock Price Prediction Result')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Save Model

# %%
if not os.path.exists('saved_models'):
    os.makedirs('saved_models')

# Get current date for model versioning
current_date = datetime.datetime.now().strftime("%Y%m%d")
model_name = f"Amazon_RNN_model_{current_date}"

# H5
model.save(f'saved_models/{model_name}.h5')
print(f"Model saved in HDF5 format: saved_models/{model_name}.h5")

# TF SavedModel
model.export(f'saved_models/{model_name}')
print(f"Model saved in SavedModel format: saved_models/{model_name}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved in HDF5 format: saved_models/Amazon_RNN_model_20250517.h5
# INFO:tensorflow:Assets written to: saved_models/Amazon_RNN_model_20250517\assets
# INFO:tensorflow:Assets written to: saved_models/Amazon_RNN_model_20250517\assets
# Saved artifact at 'saved_models/Amazon_RNN_model_20250517'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 2, 1), dtype=tf.float32, name='keras_tensor_42')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   1746419807824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1746419809552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1746419809360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1746419806096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1746419808208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1746419809168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1746419808976: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model saved in SavedModel format: saved_models/Amazon_RNN_model_20250517

# %% [markdown]
# # Conclusion

# %% [markdown]
# Dari notebook ini, dapat dilihat bahwa model RNN yang dibuat sudah cukup baik dalam memprediksi harga saham Amazon tersebut.
#
# Berikut hasil RMSE pada data training dan validasi:
#
# - Train: 0.92
# - Validation: 3.44
#
# Error yang dihasilkan ~2-3% (kesalahan sekitar 1 hingga 3.5 dollar) dari harga saham Amazon pada data yang berkisar antara $1-$103.
# Hasil tersebut menunjukkan bahwa model tidak dapat digunakan untuk memprediksi harga saham Amazon secara akurat pada tingkat harian. Namun, model ini sudah dapat memberikan gambaran umum tentang tren harga saham Amazon pada rentang mingguan, bulanan, hingga tahunan.
#
#
#
#
# Meski begitu, berikut beberapa hal yang bisa di-improve atau dilakukan eksperimen untuk meningkatkan akurasi model:
# 1. Model atau teknik lain, seperti ARIMA (untuk statistikal), atau variasi dari RNN seperti LSTM atau GRU.
# 2. Hyperparameter tuning.
